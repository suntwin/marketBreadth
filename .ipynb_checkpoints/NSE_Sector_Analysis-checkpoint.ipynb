# %%
from seleniumextractor import SeleniumExtractor
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from decimal import *
from selenium_error import *
from configReader_WLNSE import configReader_WLNSE
import random
import logging
import logging.config
import sys
import pandas as pd
import datetime as dt
import time
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
current_date = dt.datetime.today().strftime("%m%d%Y")

# %%
def _get_config(property):
    return(configReader_WLNSE.get_setting(property))
    return(configReader_WLNSE.get_setting(property))

marketinout_loginurl = _get_config("login_link")
marketinout_username = _get_config("username")

# %%
file_path = "C://Users//Sonam//Downloads//chromedriver_win32" + "//"
wl_file_path = "C://Users//Sonam//OneDrive//Documents//watchlists//usa"+"//"

# %%
marketinout_loginurl = _get_config("login_link")
marketinout_username = _get_config("username")
selextractor = SeleniumExtractor(marketinout_loginurl)
elem = selextractor.get_elem_by_id("l")
elem.send_keys(marketinout_username)
elem = selextractor.get_elems_by_class("button")[0].click()

# %%
_match_xpath = _get_config("match_xpath")

_1_month = _get_config("1_month")
_1_month_fn = _get_config("1_month_fn")
_3_month = _get_config("3_month")
_3_month_fn = _get_config("3_month_fn")
_6_month = _get_config("6_month")
_6_month_fn = _get_config("6_month_fn")

# %%
def get_scanner_details(url,selextractor,csv_file_name):
    selextractor.driver.get(url)
    selextractor.driver.get("https://www.marketinout.com/stock-screener/csv_stocks.csv")
    #insert a wait here for few seconds for the file to be downlaoded
    time.sleep(3)
    df = pd.read_csv("C://Users//Sonam//Downloads//chromedriver_win32" + "//" + csv_file_name,encoding='latin-1')
    return df

# %%
# def generate_watchlist(wl_url,sel,file_name):
#     df = get_scanner_details(wl_url,sel,file_name)
#     symbol_str = get_watchlist(df)
#     output_file_name = file_name.split('.')[0]
#     write_watchlist(output_file_name,symbol_str)
#     #delete the filename after processing to keep the directory clean
#     os.remove(file_path+file_name)

# %%
def generate_sectorData(wl_url,sel,file_name):
    df = get_scanner_details(wl_url,sel,file_name)
    os.remove(file_path+file_name)
    return df

# %%
df2 = generate_sectorData(_3_month,selextractor,_3_month_fn)
df3 = generate_sectorData(_6_month,selextractor,_6_month_fn)
df = generate_sectorData(_1_month,selextractor,_1_month_fn)

# %%
df
# Out:
#             Symbol                             Name                Industry  \
# 0        3PLAND.NS             3P Land Holdings Ltd                     NaN
# 1         BSHSL.NS    Bombay Super Hybrid Seeds Ltd     Agricultural Inputs
# 2    PONNIERODE.NS         Ponni Sugars (Erode) Ltd           Confectioners
# 3        MAGNUM.NS              Magnum Ventures Ltd  Paper & Paper Products
# 4    BLBLIMITED.NS                          BLB Ltd         Capital Markets
# ..             ...                              ...                     ...
# 191     GRAVITA.NS                Gravita India Ltd       Metal Fabrication
# 192         M_M.NS          Mahindra & Mahindra Ltd      Auto Manufacturers
# 193        IRFC.NS  Indian Railway Finance Corp Ltd         Credit Services
# 194  TATAINVEST.NS         Tata Investment Corp Ltd         Capital Markets
# 195     SBILIFE.NS   SBI Life Insurance Company Ltd        Insurance - Life
#
#                  Sector Exchange     Cap mln     Last  Change  Change %  \
# 0                   NaN      NSE      308.70    33.20   -1.75     -5.01
# 1       Basic Materials      NSE    32924.00   363.10   17.25      4.99
# 2    Consumer Defensive      NSE     4698.41   576.65   30.45      5.57
# 3       Basic Materials      NSE     1132.57    30.15    0.70      2.38
# 4    Financial Services      NSE     1767.54    35.25    2.00      6.02
# ..                  ...      ...         ...      ...     ...       ...
# 191         Industrials      NSE    30598.00   443.20   20.20      4.78
# 192   Consumer Cyclical      NSE  1570646.00  1328.15    8.25      0.63
# 193  Financial Services      NSE   433884.00    33.95    1.20      3.66
# 194  Financial Services      NSE   116205.00  2285.25   11.05      0.49
# 195  Financial Services      NSE  1314040.00  1312.95   -2.75     -0.21
#
#        Volume  ...    Adr   Adr2    Advol  Percent_float  3_mths_rs  6mths_rs  \
# 0      380958  ...   6.92   1.41     2.07            NaN      99.15     97.32
# 1      362021  ...   4.41  10.79    32.05          13.42      99.89     99.89
# 2      524941  ...   8.92  39.29   205.76          40.16      99.52     98.17
# 3     2146542  ...   7.25   1.59    12.67          41.07      99.63     99.14
# 4      630778  ...  11.39   2.93    17.35           8.85      98.41     96.51
# ..        ...  ...    ...    ...      ...            ...        ...       ...
# 191    574690  ...   4.98  21.11   159.50          18.58      91.57     93.99
# 192   2600139  ...   2.21  27.66  2544.58          66.31      70.48     62.53
# 193  75271632  ...   5.53   1.75  2476.66          13.64      97.35     92.06
# 194     44238  ...   3.42  71.47   126.65          24.08      34.61     91.79
# 195   1214977  ...   2.23  27.86  1261.80          42.17      67.78     60.76
#
#      1_mths_rs  Weekly_ib  3wtc  Weekly_chg
# 0        99.95        0.0   0.0       32.53
# 1        99.90        0.0   0.0       27.56
# 2        99.79        0.0   0.0       22.80
# 3        99.69        0.0   0.0        8.84
# 4        99.59        1.0   0.0       -3.42
# ..         ...        ...   ...         ...
# 191      80.50        0.0   0.0        2.77
# 192      80.45        0.0   0.0        5.00
# 193      80.34        0.0   0.0        3.82
# 194      80.29        0.0   0.0        9.17
# 195      80.03        0.0   0.0        3.46
#
# [196 rows x 24 columns]

# %%
df_filtered = df[df['Rs'] > 89 ]
df_filtered2 = df2[df2['Rs'] > 89 ]
df_filtered3 = df3[df3['Rs'] > 89 ]

# %%
df_filtered
# Out:
#             Symbol                           Name                Industry  \
# 0        3PLAND.NS           3P Land Holdings Ltd                     NaN
# 1         BSHSL.NS  Bombay Super Hybrid Seeds Ltd     Agricultural Inputs
# 2    PONNIERODE.NS       Ponni Sugars (Erode) Ltd           Confectioners
# 3        MAGNUM.NS            Magnum Ventures Ltd  Paper & Paper Products
# 4    BLBLIMITED.NS                        BLB Ltd         Capital Markets
# ..             ...                            ...                     ...
# 112    CHOICEIN.NS       Choice International Ltd         Capital Markets
# 113    SUBEXLTD.NS                      Subex Ltd  Software - Application
# 114      RECLTD.NS                        REC Ltd         Credit Services
# 115        RHIM.NS        RHI Magnesita India Ltd       Metal Fabrication
# 116        VSSL.NS    Vardhman Special Steels Ltd                   Steel
#
#                  Sector Exchange    Cap mln    Last  Change  Change %  \
# 0                   NaN      NSE     308.70   33.20   -1.75     -5.01
# 1       Basic Materials      NSE   32924.00  363.10   17.25      4.99
# 2    Consumer Defensive      NSE    4698.41  576.65   30.45      5.57
# 3       Basic Materials      NSE    1132.57   30.15    0.70      2.38
# 4    Financial Services      NSE    1767.54   35.25    2.00      6.02
# ..                  ...      ...        ...     ...     ...       ...
# 112  Financial Services      NSE   27060.00  271.10    1.35      0.50
# 113          Technology      NSE   19319.00   36.20    0.15      0.42
# 114  Financial Services      NSE  321910.00  122.80    2.15      1.78
# 115         Industrials      NSE  136372.00  866.45   29.95      3.58
# 116     Basic Materials      NSE   13235.00  324.20   20.35      6.70
#
#       Volume  ...    Adr   Adr2    Advol  Percent_float  3_mths_rs  6mths_rs  \
# 0     380958  ...   6.92   1.41     2.07            NaN      99.15     97.32
# 1     362021  ...   4.41  10.79    32.05          13.42      99.89     99.89
# 2     524941  ...   8.92  39.29   205.76          40.16      99.52     98.17
# 3    2146542  ...   7.25   1.59    12.67          41.07      99.63     99.14
# 4     630778  ...  11.39   2.93    17.35           8.85      98.41     96.51
# ..       ...  ...    ...    ...      ...            ...        ...       ...
# 112    31151  ...   3.31   8.21     8.95           2.95      75.09     79.33
# 113  5459051  ...   4.29   1.43   245.06          94.95      74.46     77.94
# 114  5902262  ...   2.93   3.39  1306.40          47.36      91.26     77.83
# 115   353250  ...   4.41  36.00   367.71          23.76      92.42     89.37
# 116   533796  ...   5.98  17.68    56.64          22.61      91.47     82.13
#
#      1_mths_rs  Weekly_ib  3wtc  Weekly_chg
# 0        99.95        0.0   0.0     32.5300
# 1        99.90        0.0   0.0     27.5600
# 2        99.79        0.0   0.0     22.8000
# 3        99.69        0.0   0.0      8.8400
# 4        99.59        1.0   0.0     -3.4200
# ..         ...        ...   ...         ...
# 112      89.57        0.0   0.0      7.8100
# 113      89.32        0.0   0.0      1.5400
# 114      89.26        0.0   0.0     -0.7276
# 115      89.16        0.0   0.0      0.4289
# 116      89.11        0.0   0.0      6.7100
#
# [117 rows x 24 columns]

# %%
fig, axs = plt.subplots(3,2,figsize=(100, 100))
plt.rc('font', size=60)    
df_filtered['Industry'].value_counts().plot(ax=axs[0,0],kind='pie',title='Industy by 1 Month')
df_filtered['Sector'].value_counts().plot(ax=axs[0,1],kind='pie',title='Sector by 1 Month')
df_filtered2['Industry'].value_counts().plot(ax=axs[1,0],kind='pie',title='Industy by 3 Month')
df_filtered2['Sector'].value_counts().plot(ax=axs[1,1],kind='pie',title='Sector by 3 Month')
df_filtered3['Industry'].value_counts().plot(ax=axs[2,0],kind='pie',title='Industy by 6 Month')
df_filtered3['Sector'].value_counts().plot(ax=axs[2,1],kind='pie',title='Sector by 6 Month')
# Out:
# C:\Users\Sonam\anaconda3\envs\IBKR_2\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:title={'center':'Sector by 1 Month'}, ylabel='Sector'>
