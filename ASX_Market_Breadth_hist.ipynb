# %%
from seleniumextractor import SeleniumExtractor
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from decimal import *
from selenium_error import *
from configReader_MB import configReader_MB
import random
import logging
import logging.config
import sys
import pandas as pd
import time

# %%
def _get_config(property):
    return(configReader_MB.get_setting(property))
    return(configReader_MB.get_setting(property))

marketinout_loginurl = _get_config("login_link")
marketinout_username = _get_config("username")

# %%
def _run_screener(sel,url,path):
    selextractor.driver.get(url)
    sel.get_elem_by_id("runScreenButton").click()
    data1 = sel.get_elem_by_xpath(path).text.split(" ")
    return(data1[0])

def _run_screener_crypto(sel,url,path):
    selextractor.driver.get(url)
    sel.get_elem_by_id("runScreenButton").click()

    #data1 = sel.get_elem_by_xpath(path).text.split(" ")

    data1 = sel.get_elem_by_id("results")
    print("data1",data1)
    nr = {"number_of_matches":0}
    for row in data1.find_elements_by_css_selector('tr'):
        if row == data1.find_elements_by_css_selector('tr')[-1]:
            # this is the last element of the loop
            for cell in row.find_elements_by_tag_name('td')[:1]:

                nr1 = cell.text.split(" ")[0]
            #print("nr1 is",row)
                for k in nr.keys():
                    nr['number_of_matches'] = nr1
    print("nr dict",nr)
    return(nr['number_of_matches'])

def _run_screener_crypto_hist(sel,url,path):

    left_button_xpath = "/html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a"
    date_xpath = "/html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]"
    sel.get_elem_by_xpath(left_button_xpath).click()
    #sel.get_elem_by_id("runScreenButton").click()

    date_str = sel.get_elem_by_xpath(date_xpath).text.split(" ")[1]

    data1 = sel.get_elem_by_id("results")
    print("data1",data1)
    nr = {"number_of_matches":0,"date":""}
    for row in data1.find_elements_by_css_selector('tr'):
        if row == data1.find_elements_by_css_selector('tr')[-1]:
            # this is the last element of the loop
            for cell in row.find_elements_by_tag_name('td')[:1]:

                nr1 = cell.text.split(" ")[0]
            #print("nr1 is",row)
                for k in nr.keys():
                    nr['number_of_matches'] = nr1
    #print("nr dict",nr)
    nr['date']=date_str
    return(nr)

# %%
def _save_csv(file_name,datalist):
    date_list=[]
    count_list=[]
    for i in range(len(datalist)):
        print("record",datalist[i])
        #df.append(pd.DataFrame(datalist[i], index=[0]), ignore_index=True)

        date_list.append(datalist[i]['date'])
        count_list.append(datalist[i]['number_of_matches'])
    #date_ser = pd.to_datetime(pd.Series(df.TimeReviewed))
    date_ser = pd.to_datetime(pd.Series(date_list))
    date_ser = date_ser.dt.strftime('%d/%m/%Y')
    count_ser = pd.Series(count_list)
    df = pd.DataFrame()
    df['date'] = date_ser
    df['count'] = count_ser
    #change the date format

    print(df)

    df.to_csv(file_name,index=False)

# %%
marketinout_loginurl = _get_config("login_link")
marketinout_username = _get_config("username")
selextractor = SeleniumExtractor(marketinout_loginurl)
elem = selextractor.get_elem_by_id("l")
elem.send_keys(marketinout_username)
elem = selextractor.get_elems_by_class("button")[0].click()

# %%
_match_xpath = _get_config("match_xpath")
_20sma_url = _get_config("20sma")
go_back_period = 365
#go_back_period = 101
selextractor.driver.get(_20sma_url)
#selextractor.get_elem_by_id("runScreenButton").click()
df = pd.DataFrame()
data_list =[]
for i in range(go_back_period):
        #url = _20sma_url + '&mov=' + '-' + i
    time.sleep(3)
    _20sma_up_count = _run_screener_crypto_hist(selextractor, _20sma_url, _match_xpath)
    print(_20sma_up_count['date'],_20sma_up_count['number_of_matches'])
    data_list.append(_20sma_up_count)
    #print(data_list)


    _save_csv("50sma_down.csv",data_list)
# Out:
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="bf9115ec-b3b3-4b5b-8059-cc97341af291")>
# 04/27/2023 1573
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
#          date count
# 0  27/04/2023  1573
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="37b40cd8-fffd-4ebe-8ce4-526e58da1cae")>
# 04/26/2023 1579
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="0dd1bf6d-1735-411b-a9f6-65063f58c73b")>
# 04/25/2023 1314
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="70ec298a-8122-4a1a-98c8-b630972b226e")>
# 04/24/2023 1296
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="b01d3cf6-b461-404f-a325-6d527d8dd4a5")>
# 04/23/2023 1351
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# 4  23/04/2023  1351
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="1557831f-b1f4-4a72-b8e2-8e2c3f6dd1a4")>
# 04/22/2023 1351
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# 4  23/04/2023  1351
# 5  22/04/2023  1351
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="51cb1f48-2d02-4954-80a4-e288f3df9600")>
# 04/21/2023 1351
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# 4  23/04/2023  1351
# 5  22/04/2023  1351
# 6  21/04/2023  1351
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="0f0b034f-ede2-45f0-a353-3043130d6112")>
# 04/20/2023 1266
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# 4  23/04/2023  1351
# 5  22/04/2023  1351
# 6  21/04/2023  1351
# 7  20/04/2023  1266
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="1b506588-7fb6-4d3e-9657-68b09e432aeb")>
# 04/19/2023 1309
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# 4  23/04/2023  1351
# 5  22/04/2023  1351
# 6  21/04/2023  1351
# 7  20/04/2023  1266
# 8  19/04/2023  1309
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="98f7c0cc-791c-4979-8f7a-7ee990484fdc")>
# 04/18/2023 1234
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
#          date count
# 0  27/04/2023  1573
# 1  26/04/2023  1579
# 2  25/04/2023  1314
# 3  24/04/2023  1296
# 4  23/04/2023  1351
# 5  22/04/2023  1351
# 6  21/04/2023  1351
# 7  20/04/2023  1266
# 8  19/04/2023  1309
# 9  18/04/2023  1234
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="4cf8ffbe-5ea5-4c8e-b5ee-919000bebbbf")>
# 04/17/2023 1349
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="75b6e4a6-32a4-4873-af32-0a42be8986e8")>
# 04/16/2023 1363
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="e947a913-e31a-44c7-9650-30a82c8e86c2")>
# 04/15/2023 1363
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="5eb6292a-12e3-426d-b0e0-5fd6942178b7")>
# 04/14/2023 1363
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="93ef6150-4fdb-4aba-b106-19202e373abc")>
# 04/13/2023 1463
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="89837c76-766c-4321-8bf6-48f9ad3b41aa")>
# 04/12/2023 1474
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="a94fc9c3-c4d0-4de2-93c4-d81a85dd83b1")>
# 04/11/2023 1606
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="d64cbca8-6872-4744-839c-2ee0e73d9ad7")>
# 04/10/2023 1753
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="4358f48c-1fb4-4dc8-9c23-df3323fcc673")>
# 04/09/2023 1929
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="b06552cf-ad2f-4944-af4d-81207e23747e")>
# 04/08/2023 1929
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="14c6aab7-3c07-40f7-8471-8ff9019b6ad4")>
# 04/07/2023 1929
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="288a4e30-af1c-4797-83c6-acfeb10ce133")>
# 04/06/2023 1960
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="45b4f7e0-529d-4ffb-a230-b144457eb489")>
# 04/05/2023 1643
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="08eefe2a-dcab-4103-bb80-31b7e3a17aee")>
# 04/04/2023 1186
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
# record {'number_of_matches': '1186', 'date': '04/04/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# 23  04/04/2023  1186
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="1fd784ea-2e1a-440d-9fb8-0a6b176e83ac")>
# 04/03/2023 1131
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
# record {'number_of_matches': '1186', 'date': '04/04/2023'}
# record {'number_of_matches': '1131', 'date': '04/03/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# 23  04/04/2023  1186
# 24  03/04/2023  1131
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="f4e867c2-c9bd-479d-b0f6-b2a470301cfb")>
# 04/02/2023 1343
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
# record {'number_of_matches': '1186', 'date': '04/04/2023'}
# record {'number_of_matches': '1131', 'date': '04/03/2023'}
# record {'number_of_matches': '1343', 'date': '04/02/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# 23  04/04/2023  1186
# 24  03/04/2023  1131
# 25  02/04/2023  1343
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="5a14bb26-022c-4e4a-93d4-2a73ab2c64f5")>
# 04/01/2023 1343
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
# record {'number_of_matches': '1186', 'date': '04/04/2023'}
# record {'number_of_matches': '1131', 'date': '04/03/2023'}
# record {'number_of_matches': '1343', 'date': '04/02/2023'}
# record {'number_of_matches': '1343', 'date': '04/01/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# 23  04/04/2023  1186
# 24  03/04/2023  1131
# 25  02/04/2023  1343
# 26  01/04/2023  1343
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="6befdf6c-34ab-48c3-a527-a3b8c5fa165a")>
# 03/31/2023 1343
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
# record {'number_of_matches': '1186', 'date': '04/04/2023'}
# record {'number_of_matches': '1131', 'date': '04/03/2023'}
# record {'number_of_matches': '1343', 'date': '04/02/2023'}
# record {'number_of_matches': '1343', 'date': '04/01/2023'}
# record {'number_of_matches': '1343', 'date': '03/31/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# 23  04/04/2023  1186
# 24  03/04/2023  1131
# 25  02/04/2023  1343
# 26  01/04/2023  1343
# 27  31/03/2023  1343
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]
# data1 <selenium.webdriver.remote.webelement.WebElement (session="692ff04380f4ed7e2100f22d61d4a779", element="05d6739a-bc4d-4600-a68c-c70cbb44b785")>
# 03/30/2023 1435
# record {'number_of_matches': '1573', 'date': '04/27/2023'}
# record {'number_of_matches': '1579', 'date': '04/26/2023'}
# record {'number_of_matches': '1314', 'date': '04/25/2023'}
# record {'number_of_matches': '1296', 'date': '04/24/2023'}
# record {'number_of_matches': '1351', 'date': '04/23/2023'}
# record {'number_of_matches': '1351', 'date': '04/22/2023'}
# record {'number_of_matches': '1351', 'date': '04/21/2023'}
# record {'number_of_matches': '1266', 'date': '04/20/2023'}
# record {'number_of_matches': '1309', 'date': '04/19/2023'}
# record {'number_of_matches': '1234', 'date': '04/18/2023'}
# record {'number_of_matches': '1349', 'date': '04/17/2023'}
# record {'number_of_matches': '1363', 'date': '04/16/2023'}
# record {'number_of_matches': '1363', 'date': '04/15/2023'}
# record {'number_of_matches': '1363', 'date': '04/14/2023'}
# record {'number_of_matches': '1463', 'date': '04/13/2023'}
# record {'number_of_matches': '1474', 'date': '04/12/2023'}
# record {'number_of_matches': '1606', 'date': '04/11/2023'}
# record {'number_of_matches': '1753', 'date': '04/10/2023'}
# record {'number_of_matches': '1929', 'date': '04/09/2023'}
# record {'number_of_matches': '1929', 'date': '04/08/2023'}
# record {'number_of_matches': '1929', 'date': '04/07/2023'}
# record {'number_of_matches': '1960', 'date': '04/06/2023'}
# record {'number_of_matches': '1643', 'date': '04/05/2023'}
# record {'number_of_matches': '1186', 'date': '04/04/2023'}
# record {'number_of_matches': '1131', 'date': '04/03/2023'}
# record {'number_of_matches': '1343', 'date': '04/02/2023'}
# record {'number_of_matches': '1343', 'date': '04/01/2023'}
# record {'number_of_matches': '1343', 'date': '03/31/2023'}
# record {'number_of_matches': '1435', 'date': '03/30/2023'}
#           date count
# 0   27/04/2023  1573
# 1   26/04/2023  1579
# 2   25/04/2023  1314
# 3   24/04/2023  1296
# 4   23/04/2023  1351
# 5   22/04/2023  1351
# 6   21/04/2023  1351
# 7   20/04/2023  1266
# 8   19/04/2023  1309
# 9   18/04/2023  1234
# 10  17/04/2023  1349
# 11  16/04/2023  1363
# 12  15/04/2023  1363
# 13  14/04/2023  1363
# 14  13/04/2023  1463
# 15  12/04/2023  1474
# 16  11/04/2023  1606
# 17  10/04/2023  1753
# 18  09/04/2023  1929
# 19  08/04/2023  1929
# 20  07/04/2023  1929
# 21  06/04/2023  1960
# 22  05/04/2023  1643
# 23  04/04/2023  1186
# 24  03/04/2023  1131
# 25  02/04/2023  1343
# 26  01/04/2023  1343
# 27  31/03/2023  1343
# ...
# record {'number_of_matches': '797', 'date': '03/08/2023'}
# record {'number_of_matches': '836', 'date': '03/07/2023'}
# record {'number_of_matches': '902', 'date': '03/06/2023'}
# record {'number_of_matches': '955', 'date': '03/05/2023'}
# record {'number_of_matches': '955', 'date': '03/04/2023'}
# record {'number_of_matches': '955', 'date': '03/03/2023'}
# record {'number_of_matches': '1079', 'date': '03/02/2023'}
# record {'number_of_matches': '1084', 'date': '03/01/2023'}
# record {'number_of_matches': '1103', 'date': '02/28/2023'}
# record {'number_of_matches': '1155', 'date': '02/27/2023'}
# record {'number_of_matches': '1209', 'date': '02/26/2023'}
# record {'number_of_matches': '1209', 'date': '02/25/2023'}
# record {'number_of_matches': '1209', 'date': '02/24/2023'}
# record {'number_of_matches': '1329', 'date': '02/23/2023'}
# record {'number_of_matches': '1329', 'date': '02/22/2023'}
# record {'number_of_matches': '1181', 'date': '02/21/2023'}
# record {'number_of_matches': '1197', 'date': '02/20/2023'}
# record {'number_of_matches': '1326', 'date': '02/19/2023'}
# record {'number_of_matches': '1326', 'date': '02/18/2023'}
# record {'number_of_matches': '1326', 'date': '02/17/2023'}
# record {'number_of_matches': '1287', 'date': '02/16/2023'}
# record {'number_of_matches': '1457', 'date': '02/15/2023'}
# record {'number_of_matches': '1318', 'date': '02/14/2023'}
# record {'number_of_matches': '1486', 'date': '02/13/2023'}
# record {'number_of_matches': '1377', 'date': '02/12/2023'}
# record {'number_of_matches': '1377', 'date': '02/11/2023'}
# record {'number_of_matches': '1377', 'date': '02/10/2023'}
# record {'number_of_matches': '1301', 'date': '02/09/2023'}
# record {'number_of_matches': '1373', 'date': '02/08/2023'}
# record {'number_of_matches': '1435', 'date': '02/07/2023'}
# record {'number_of_matches': '1461', 'date': '02/06/2023'}
# record {'number_of_matches': '1598', 'date': '02/05/2023'}
# record {'number_of_matches': '1598', 'date': '02/04/2023'}
# record {'number_of_matches': '1598', 'date': '02/03/2023'}
# record {'number_of_matches': '1474', 'date': '02/02/2023'}
# record {'number_of_matches': '1370', 'date': '02/01/2023'}
# record {'number_of_matches': '1367', 'date': '01/31/2023'}
# record {'number_of_matches': '1501', 'date': '01/30/2023'}
# record {'number_of_matches': '1439', 'date': '01/29/2023'}
# record {'number_of_matches': '1439', 'date': '01/28/2023'}
# record {'number_of_matches': '1439', 'date': '01/27/2023'}
# record {'number_of_matches': '1426', 'date': '01/26/2023'}
# record {'number_of_matches': '1433', 'date': '01/25/2023'}
# record {'number_of_matches': '1553', 'date': '01/24/2023'}
# record {'number_of_matches': '1796', 'date': '01/23/2023'}
# record {'number_of_matches': '2092', 'date': '01/22/2023'}
# record {'number_of_matches': '2092', 'date': '01/21/2023'}
# record {'number_of_matches': '2092', 'date': '01/20/2023'}
# record {'number_of_matches': '2254', 'date': '01/19/2023'}
# record {'number_of_matches': '2204', 'date': '01/18/2023'}
# record {'number_of_matches': '2461', 'date': '01/17/2023'}
# record {'number_of_matches': '2611', 'date': '01/16/2023'}
# record {'number_of_matches': '2531', 'date': '01/15/2023'}
# record {'number_of_matches': '2531', 'date': '01/14/2023'}
# record {'number_of_matches': '2531', 'date': '01/13/2023'}
# record {'number_of_matches': '2442', 'date': '01/12/2023'}
# record {'number_of_matches': '2353', 'date': '01/11/2023'}
# record {'number_of_matches': '2539', 'date': '01/10/2023'}
# record {'number_of_matches': '2635', 'date': '01/09/2023'}
# record {'number_of_matches': '2635', 'date': '01/08/2023'}
# record {'number_of_matches': '2635', 'date': '01/07/2023'}
# record {'number_of_matches': '2635', 'date': '01/06/2023'}
# record {'number_of_matches': '2698', 'date': '01/05/2023'}
# record {'number_of_matches': '2629', 'date': '01/04/2023'}
# record {'number_of_matches': '2362', 'date': '01/03/2023'}
# record {'number_of_matches': '2362', 'date': '01/02/2023'}
# record {'number_of_matches': '2362', 'date': '01/01/2023'}
# record {'number_of_matches': '2362', 'date': '12/31/2022'}
# record {'number_of_matches': '2362', 'date': '12/30/2022'}
# record {'number_of_matches': '2406', 'date': '12/29/2022'}
# record {'number_of_matches': '2456', 'date': '12/28/2022'}
# record {'number_of_matches': '2418', 'date': '12/27/2022'}
# record {'number_of_matches': '2543', 'date': '12/26/2022'}
# record {'number_of_matches': '2570', 'date': '12/25/2022'}
# record {'number_of_matches': '2570', 'date': '12/24/2022'}
# record {'number_of_matches': '2570', 'date': '12/23/2022'}
# record {'number_of_matches': '2444', 'date': '12/22/2022'}
# record {'number_of_matches': '2626', 'date': '12/21/2022'}
# record {'number_of_matches': '2462', 'date': '12/20/2022'}
# record {'number_of_matches': '1957', 'date': '12/19/2022'}
# record {'number_of_matches': '1843', 'date': '12/18/2022'}
# record {'number_of_matches': '1843', 'date': '12/17/2022'}
# record {'number_of_matches': '1843', 'date': '12/16/2022'}
# record {'number_of_matches': '1586', 'date': '12/15/2022'}
# record {'number_of_matches': '1599', 'date': '12/14/2022'}
# record {'number_of_matches': '1727', 'date': '12/13/2022'}
# record {'number_of_matches': '1765', 'date': '12/12/2022'}
# record {'number_of_matches': '1733', 'date': '12/11/2022'}
# record {'number_of_matches': '1733', 'date': '12/10/2022'}
# record {'number_of_matches': '1733', 'date': '12/09/2022'}
# record {'number_of_matches': '1919', 'date': '12/08/2022'}
# record {'number_of_matches': '1841', 'date': '12/07/2022'}
# record {'number_of_matches': '1909', 'date': '12/06/2022'}
# record {'number_of_matches': '1822', 'date': '12/05/2022'}
# record {'number_of_matches': '1767', 'date': '12/04/2022'}
# record {'number_of_matches': '1767', 'date': '12/03/2022'}
# record {'number_of_matches': '1767', 'date': '12/02/2022'}
# record {'number_of_matches': '1400', 'date': '12/01/2022'}
# record {'number_of_matches': '1342', 'date': '11/30/2022'}
# record {'number_of_matches': '1202', 'date': '11/29/2022'}
# record {'number_of_matches': '1130', 'date': '11/28/2022'}
# record {'number_of_matches': '1111', 'date': '11/27/2022'}
# record {'number_of_matches': '1111', 'date': '11/26/2022'}
# record {'number_of_matches': '1111', 'date': '11/25/2022'}
# record {'number_of_matches': '1177', 'date': '11/24/2022'}
# record {'number_of_matches': '1421', 'date': '11/23/2022'}
# record {'number_of_matches': '1421', 'date': '11/22/2022'}
# record {'number_of_matches': '1644', 'date': '11/21/2022'}
# record {'number_of_matches': '1746', 'date': '11/20/2022'}
# record {'number_of_matches': '1746', 'date': '11/19/2022'}
# record {'number_of_matches': '1746', 'date': '11/18/2022'}
# record {'number_of_matches': '1801', 'date': '11/17/2022'}
# record {'number_of_matches': '1965', 'date': '11/16/2022'}
# record {'number_of_matches': '1992', 'date': '11/15/2022'}
# record {'number_of_matches': '2014', 'date': '11/14/2022'}
# record {'number_of_matches': '1831', 'date': '11/13/2022'}
# record {'number_of_matches': '1831', 'date': '11/12/2022'}
# record {'number_of_matches': '1831', 'date': '11/11/2022'}
# record {'number_of_matches': '2103', 'date': '11/10/2022'}
# record {'number_of_matches': '2023', 'date': '11/09/2022'}
# record {'number_of_matches': '2012', 'date': '11/08/2022'}
# record {'number_of_matches': '2217', 'date': '11/07/2022'}
# record {'number_of_matches': '2389', 'date': '11/06/2022'}
# record {'number_of_matches': '2389', 'date': '11/05/2022'}
# record {'number_of_matches': '2389', 'date': '11/04/2022'}
# record {'number_of_matches': '2185', 'date': '11/03/2022'}
# record {'number_of_matches': '2185', 'date': '11/02/2022'}
# record {'number_of_matches': '2152', 'date': '11/01/2022'}
# record {'number_of_matches': '2146', 'date': '10/31/2022'}
# record {'number_of_matches': '2439', 'date': '10/30/2022'}
# record {'number_of_matches': '2439', 'date': '10/29/2022'}
# record {'number_of_matches': '2439', 'date': '10/28/2022'}
# record {'number_of_matches': '2327', 'date': '10/27/2022'}
# record {'number_of_matches': '2206', 'date': '10/26/2022'}
# record {'number_of_matches': '2348', 'date': '10/25/2022'}
# record {'number_of_matches': '2529', 'date': '10/24/2022'}
# record {'number_of_matches': '2530', 'date': '10/23/2022'}
# record {'number_of_matches': '2530', 'date': '10/22/2022'}
# record {'number_of_matches': '2530', 'date': '10/21/2022'}
# record {'number_of_matches': '2420', 'date': '10/20/2022'}
# record {'number_of_matches': '2324', 'date': '10/19/2022'}
# record {'number_of_matches': '2417', 'date': '10/18/2022'}
# record {'number_of_matches': '2642', 'date': '10/17/2022'}
# record {'number_of_matches': '2519', 'date': '10/16/2022'}
# record {'number_of_matches': '2519', 'date': '10/15/2022'}
# record {'number_of_matches': '2519', 'date': '10/14/2022'}
# record {'number_of_matches': '2845', 'date': '10/13/2022'}
# record {'number_of_matches': '2712', 'date': '10/12/2022'}
# record {'number_of_matches': '2721', 'date': '10/11/2022'}
# record {'number_of_matches': '2387', 'date': '10/10/2022'}
# record {'number_of_matches': '2387', 'date': '10/09/2022'}
# record {'number_of_matches': '2387', 'date': '10/08/2022'}
# record {'number_of_matches': '2387', 'date': '10/07/2022'}
# record {'number_of_matches': '2263', 'date': '10/06/2022'}
# record {'number_of_matches': '2425', 'date': '10/05/2022'}
# record {'number_of_matches': '2426', 'date': '10/04/2022'}
# record {'number_of_matches': '2928', 'date': '10/03/2022'}
# record {'number_of_matches': '2892', 'date': '10/02/2022'}
# record {'number_of_matches': '2892', 'date': '10/01/2022'}
# record {'number_of_matches': '2892', 'date': '09/30/2022'}
# record {'number_of_matches': '2719', 'date': '09/29/2022'}
# record {'number_of_matches': '2820', 'date': '09/28/2022'}
# record {'number_of_matches': '2696', 'date': '09/27/2022'}
# record {'number_of_matches': '2739', 'date': '09/26/2022'}
# record {'number_of_matches': '2238', 'date': '09/25/2022'}
# record {'number_of_matches': '2238', 'date': '09/24/2022'}
# record {'number_of_matches': '2238', 'date': '09/23/2022'}
# record {'number_of_matches': '2238', 'date': '09/22/2022'}
# record {'number_of_matches': '2202', 'date': '09/21/2022'}
# record {'number_of_matches': '1955', 'date': '09/20/2022'}
# record {'number_of_matches': '2084', 'date': '09/19/2022'}
# record {'number_of_matches': '2084', 'date': '09/18/2022'}
# record {'number_of_matches': '2084', 'date': '09/17/2022'}
# record {'number_of_matches': '2084', 'date': '09/16/2022'}
# record {'number_of_matches': '1892', 'date': '09/15/2022'}
# record {'number_of_matches': '1887', 'date': '09/14/2022'}
# record {'number_of_matches': '1536', 'date': '09/13/2022'}
# record {'number_of_matches': '1559', 'date': '09/12/2022'}
# record {'number_of_matches': '1671', 'date': '09/11/2022'}
# record {'number_of_matches': '1671', 'date': '09/10/2022'}
# record {'number_of_matches': '1671', 'date': '09/09/2022'}
# record {'number_of_matches': '1778', 'date': '09/08/2022'}
# record {'number_of_matches': '2158', 'date': '09/07/2022'}
# record {'number_of_matches': '1929', 'date': '09/06/2022'}
# record {'number_of_matches': '1934', 'date': '09/05/2022'}
# record {'number_of_matches': '1869', 'date': '09/04/2022'}
# record {'number_of_matches': '1869', 'date': '09/03/2022'}
# record {'number_of_matches': '1869', 'date': '09/02/2022'}
# record {'number_of_matches': '1748', 'date': '09/01/2022'}
# record {'number_of_matches': '1402', 'date': '08/31/2022'}
# record {'number_of_matches': '1333', 'date': '08/30/2022'}
# record {'number_of_matches': '1497', 'date': '08/29/2022'}
# record {'number_of_matches': '1165', 'date': '08/28/2022'}
# record {'number_of_matches': '1165', 'date': '08/27/2022'}
# record {'number_of_matches': '1165', 'date': '08/26/2022'}
# record {'number_of_matches': '1175', 'date': '08/25/2022'}
# record {'number_of_matches': '1271', 'date': '08/24/2022'}
# record {'number_of_matches': '1362', 'date': '08/23/2022'}
# record {'number_of_matches': '1244', 'date': '08/22/2022'}
# record {'number_of_matches': '1212', 'date': '08/21/2022'}
# record {'number_of_matches': '1212', 'date': '08/20/2022'}
# record {'number_of_matches': '1212', 'date': '08/19/2022'}
# record {'number_of_matches': '1277', 'date': '08/18/2022'}
# record {'number_of_matches': '1195', 'date': '08/17/2022'}
# record {'number_of_matches': '1405', 'date': '08/16/2022'}
# record {'number_of_matches': '1400', 'date': '08/15/2022'}
# record {'number_of_matches': '1355', 'date': '08/14/2022'}
# record {'number_of_matches': '1355', 'date': '08/13/2022'}
# record {'number_of_matches': '1355', 'date': '08/12/2022'}
# record {'number_of_matches': '1642', 'date': '08/11/2022'}
# record {'number_of_matches': '1642', 'date': '08/10/2022'}
# record {'number_of_matches': '1535', 'date': '08/09/2022'}
# record {'number_of_matches': '1404', 'date': '08/08/2022'}
# record {'number_of_matches': '1341', 'date': '08/07/2022'}
# record {'number_of_matches': '1341', 'date': '08/06/2022'}
# record {'number_of_matches': '1341', 'date': '08/05/2022'}
# record {'number_of_matches': '1491', 'date': '08/04/2022'}
# record {'number_of_matches': '1521', 'date': '08/03/2022'}
# record {'number_of_matches': '1382', 'date': '08/02/2022'}
# record {'number_of_matches': '1081', 'date': '08/01/2022'}
# record {'number_of_matches': '1251', 'date': '07/31/2022'}
# record {'number_of_matches': '1251', 'date': '07/30/2022'}
# record {'number_of_matches': '1251', 'date': '07/29/2022'}
# record {'number_of_matches': '1123', 'date': '07/28/2022'}
# record {'number_of_matches': '1152', 'date': '07/27/2022'}
# record {'number_of_matches': '1138', 'date': '07/26/2022'}
# record {'number_of_matches': '1222', 'date': '07/25/2022'}
# record {'number_of_matches': '1131', 'date': '07/24/2022'}
# record {'number_of_matches': '1131', 'date': '07/23/2022'}
# record {'number_of_matches': '1131', 'date': '07/22/2022'}
# record {'number_of_matches': '1139', 'date': '07/21/2022'}
# record {'number_of_matches': '1325', 'date': '07/20/2022'}
# record {'number_of_matches': '1685', 'date': '07/19/2022'}
# record {'number_of_matches': '1797', 'date': '07/18/2022'}
# record {'number_of_matches': '1797', 'date': '07/17/2022'}
# record {'number_of_matches': '1797', 'date': '07/16/2022'}
# record {'number_of_matches': '1797', 'date': '07/15/2022'}
# record {'number_of_matches': '1709', 'date': '07/14/2022'}
# record {'number_of_matches': '1790', 'date': '07/13/2022'}
# record {'number_of_matches': '1941', 'date': '07/12/2022'}
# record {'number_of_matches': '1554', 'date': '07/11/2022'}
# record {'number_of_matches': '1877', 'date': '07/10/2022'}
# record {'number_of_matches': '1877', 'date': '07/09/2022'}
# record {'number_of_matches': '1877', 'date': '07/08/2022'}
# record {'number_of_matches': '1886', 'date': '07/07/2022'}
# record {'number_of_matches': '2013', 'date': '07/06/2022'}
# record {'number_of_matches': '1836', 'date': '07/05/2022'}
# record {'number_of_matches': '1891', 'date': '07/04/2022'}
# record {'number_of_matches': '2129', 'date': '07/03/2022'}
# record {'number_of_matches': '2129', 'date': '07/02/2022'}
# record {'number_of_matches': '2129', 'date': '07/01/2022'}
# record {'number_of_matches': '1888', 'date': '06/30/2022'}
# record {'number_of_matches': '1654', 'date': '06/29/2022'}
# record {'number_of_matches': '1586', 'date': '06/28/2022'}
# record {'number_of_matches': '1846', 'date': '06/27/2022'}
# record {'number_of_matches': '1998', 'date': '06/26/2022'}
# record {'number_of_matches': '1998', 'date': '06/25/2022'}
# record {'number_of_matches': '1998', 'date': '06/24/2022'}
# record {'number_of_matches': '2207', 'date': '06/23/2022'}
# record {'number_of_matches': '2309', 'date': '06/22/2022'}
# record {'number_of_matches': '2252', 'date': '06/21/2022'}
# record {'number_of_matches': '2674', 'date': '06/20/2022'}
# record {'number_of_matches': '2483', 'date': '06/19/2022'}
# record {'number_of_matches': '2483', 'date': '06/18/2022'}
#            date count
# 0    27/04/2023  1573
# 1    26/04/2023  1579
# 2    25/04/2023  1314
# 3    24/04/2023  1296
# 4    23/04/2023  1351
# ..          ...   ...
# 309  22/06/2022  2309
# 310  21/06/2022  2252
# 311  20/06/2022  2674
# 312  19/06/2022  2483
# 313  18/06/2022  2483
#
# [314 rows x 2 columns]
# xpath /html/body/table[2]/tbody/tr/td[2]/table[3]/tbody/tr/td/table[1]/tbody/tr[1]/td/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[1]/a
